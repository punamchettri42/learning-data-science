# %% [markdown]
# # visulaizing with matplotlib

# %%
# importing matlplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.style.use('classic')

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %%
# % matplotlib only will denote to the iteractive plots whereas %matplotlib inline will lead to static images of your plot

# %%
import numpy as np
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %%
# saving figures to the file
fig.savefig('my_figure.png')
#this will save it in your current working directory

# %%
# this will display the figure we saved in our working directory
from IPython.display import Image
Image('my_figure.png')

# %%
""" we should focus on capital and small letter words for the various keywords while learning and working about data science module"""
# Out:
# ' we should focus on capital and small letter words for the various keywords while learning and working about data science module'

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
# learning about matlab styled interface
plt.figure() # create a plot figure
# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))
# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 10000)
ax.plot(x, np.sin(x));

# %%
plt.plot(x,np.sin(x));
# next method for plotting above

# %%
# overline plotting
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x));

# %%
# adjusting plot line colors and styles
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name

# %%
plt.plot(x, np.sin(x - 1), color='g') 
# green

# %%
plt.plot(x, np.sin(x - 2), color='0.75') 
#grey

# %%
plt.plot(x, np.sin(x - 3), color='#FFDD44')

# %%
plt.plot(x, np.sin(x - 2)) 
# if we don't specify any color then it will automatically print the blue by default

# %%
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
# overline plotting
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
# similarly we can learn and utilize linestyle usin linestyle keyword
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');
# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':'); # dotted

# %% [markdown]
# THIS IS AMAZING

# %%
plt.plot(x, x + 0, '-g') # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r'); # dotted red

# %%
# adjusting th plot axes limit
plt.plot(x,np.sin(x))
plt.xlim(-2, 11)
plt.ylim(-1.5, 1.5);
# managing limits

# %%
# we can also directly manage the limits
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);
# managing x range and y range all in single line

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %%
plt.plot(x,np.cos(x))
plt.axis('equal');

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");
# labelling it i.e describing properly

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend();
